# %% [markdown]
# # 🚀 California Housing ML - Quick Start on Colab
#
# ## تشغيل سريع للمشروع على Google Colab
#
# اتبع الخطوات أدناه لتشغيل المشروع بالكامل:

# %% [markdown]
# ### الخطوة 1: تثبيت المكتبات المطلوبة

# %%
# !pip install -q streamlit pyngrok scikit-learn pandas numpy matplotlib seaborn plotly joblib

# %% [markdown]
# ### الخطوة 2: تحميل ملفات المشروع

# %%
# تحميل الملفات من GitHub (استبدل YOUR_USERNAME و YOUR_REPO بمعلوماتك)
# !wget -q https://raw.githubusercontent.com/YOUR_USERNAME/YOUR_REPO/main/app.py
# !wget -q https://raw.githubusercontent.com/YOUR_USERNAME/YOUR_REPO/main/california_housing_project.ipynb
print("✅ تم تحميل الملفات بنجاح!")
# !ls -la *.py *.ipynb

# %% [markdown]
# ### الخطوة 3: تشغيل Streamlit Dashboard مع ngrok

# %%
from pyngrok import ngrok
import subprocess
import time

# ⚠️ ضع الـ token الخاص بك هنا
NGROK_TOKEN = '3FghmjIhl8Oc4iIbV9Vre1J9HlH_6F5ykoVyfgacWCkGscjY9'

# ضبط الـ token
ngrok.set_auth_token(NGROK_TOKEN)

# تشغيل Streamlit في الخلفية
print("🎬 Starting Streamlit server...")
proc = subprocess.Popen(
    ['streamlit', 'run', 'app.py',
     '--server.port', '8501',
     '--server.address', 'localhost',
     '--server.headless', 'true',
     '--browser.gatherUsageStats', 'false'],
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT
)

# انتظر حتى يبدأ Streamlit
print("⏳ Waiting for Streamlit to start...")
time.sleep(8)

# إنشاء النفق
print("🔗 Creating ngrok tunnel...")
tunnel = ngrok.connect(8501)

print("\n" + "="*60)
print("✅ SUCCESS! Your Streamlit App is live!")
print("="*60)
print(f"🔗 Click here to open your app: {tunnel.public_url}")
print("="*60)
print("\n⚠️  Keep this cell running. Press Ctrl+C to stop.")

# إبقاء النفق مفتوحاً
try:
    while True:
        time.sleep(1)
except KeyboardInterrupt:
    print("\n🛑 Stopping...")
    ngrok.disconnect()
    proc.terminate()

# %% [markdown]
# ### الخطوة 4: فتح التطبيق
#
# 1. انقر على الرابط الذي ظهر أعلاه
# 2. سيفتح تطبيق Streamlit في نافذة جديدة
# 3. استكشف نتائج Regression و Classification و Clustering
#
# ---
#
# ## ملاحظات مهمة:
#
# - **لا تغلق هذه الخلية** بينما تستخدم التطبيق
# - إذا ظهر خطأ **ERR_NGROK_3200**، تأكد من صحة الـ token
# - يمكنك إعادة تشغيل Runtime إذا واجهت مشاكل
#
# ## استكشاف الأخطاء:
#
# ```python
# # إذا لم يعمل ngrok، جرب هذا الكود البديل:
# !pip install --upgrade pyngrok
#
# # تحقق من حالة حسابك على ngrok:
# # https://dashboard.ngrok.com
# ```
